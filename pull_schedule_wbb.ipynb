# %%
import json
import urllib
import pandas as pd
import numpy as np
import http
from urllib.error import URLError, HTTPError, ContentTooShortError
from datetime import datetime
import time

def download(url, num_retries=5): 
#     print('Downloading:', url)
    try: 
        time.sleep(1)
        html = urllib.request.urlopen(url).read()
    except (URLError, HTTPError, ContentTooShortError, http.client.HTTPException) as e: 
        print('Download error:', e.reason,url)
        html = None 
        if num_retries > 0: 
            if hasattr(e, 'code') and 500 <= e.code < 600: 
                time.sleep(10)
                # recursively retry 5xx HTTP errors 
                return download(url, num_retries - 1) 
    return html

def wbb_calendar(season):
    url = "http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?dates={}".format(season)
    resp = download(url=url)
    txt = json.loads(resp)['leagues'][0]['calendar']
    datenum = list(map(lambda x: x[:10].replace("-",""),txt))
    date = list(map(lambda x: x[:10],txt))
    
    year = list(map(lambda x: x[:4],txt))
    month = list(map(lambda x: x[5:7],txt))
    day = list(map(lambda x: x[8:10],txt))
    
    data = {"season": season,
            "datetime" : txt,
            "date" : date,
            "year": year,
            "month": month,
            "day": day,
            "dateURL": datenum
            
           }
    df = pd.DataFrame(data)
    df['url']="http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?dates="
    df['url']= df['url'] + df['dateURL']
    return df

wbb_calendar(2018)
# Out:
#      season           datetime        date  year month day   dateURL  \
# 0      2018  2017-11-10T08:00Z  2017-11-10  2017    11  10  20171110
# 1      2018  2017-11-11T08:00Z  2017-11-11  2017    11  11  20171111
# 2      2018  2017-11-12T08:00Z  2017-11-12  2017    11  12  20171112
# 3      2018  2017-11-13T08:00Z  2017-11-13  2017    11  13  20171113
# 4      2018  2017-11-14T08:00Z  2017-11-14  2017    11  14  20171114
# ..      ...                ...         ...   ...   ...  ..       ...
# 131    2018  2018-03-28T07:00Z  2018-03-28  2018    03  28  20180328
# 132    2018  2018-03-29T07:00Z  2018-03-29  2018    03  29  20180329
# 133    2018  2018-03-30T07:00Z  2018-03-30  2018    03  30  20180330
# 134    2018  2018-03-31T07:00Z  2018-03-31  2018    03  31  20180331
# 135    2018  2018-04-01T07:00Z  2018-04-01  2018    04  01  20180401
#
#                                                    url
# 0    http://site.api.espn.com/apis/site/v2/sports/b...
# 1    http://site.api.espn.com/apis/site/v2/sports/b...
# 2    http://site.api.espn.com/apis/site/v2/sports/b...
# 3    http://site.api.espn.com/apis/site/v2/sports/b...
# 4    http://site.api.espn.com/apis/site/v2/sports/b...
# ..                                                 ...
# 131  http://site.api.espn.com/apis/site/v2/sports/b...
# 132  http://site.api.espn.com/apis/site/v2/sports/b...
# 133  http://site.api.espn.com/apis/site/v2/sports/b...
# 134  http://site.api.espn.com/apis/site/v2/sports/b...
# 135  http://site.api.espn.com/apis/site/v2/sports/b...
#
# [136 rows x 8 columns]

# %%
pd.set_option('display.max_colwidth',None)
schedule = {}
for x in range(2001,2022):
    full_schedule = cbb_calendar(x)
    full_schedule.to_json(orient='records')
    schedule[x]=full_schedule
    
data_dict = {
    key: schedule[key].to_dict(orient='records')
    for key in schedule.keys()
}

with open('wbb_calendar.json','w') as fp:
    json.dump(
    data_dict,
    fp,
    indent=4,
    sort_keys=True)

# %%
import json
import urllib
import pandas as pd
import numpy as np
import http
from urllib.error import URLError, HTTPError, ContentTooShortError
from datetime import datetime
import time

def download(url, num_retries=10): 
#     print('Downloading:', url)
    try: 
        time.sleep(1)
        html = urllib.request.urlopen(url).read()
    except (URLError, HTTPError, ContentTooShortError, http.client.HTTPException) as e: 
        print('Download error:', e.reason,url)
        html = None 
        if num_retries > 0: 
            if hasattr(e, 'code') and 500 <= e.code < 600: 
                time.sleep(10)
                # recursively retry 5xx HTTP errors 
                return download(url, num_retries - 1)
    return html

def wbb_schedule(year):
    url = "http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?dates={}".format(year)
    resp = download(url=url)
    txt = json.loads(resp)['leagues'][0]['calendar']
#     print(len(txt))
    txt = list(map(lambda x: x[:10].replace("-",""),txt))
    
    ev = pd.DataFrame()
    i=0
    for date in txt:
        print(f"Working on {year}: {i+1} of {len(txt)}, date: {txt[i]}")
        url = "http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates={}&limit=1000".format(date)
        resp = download(url=url)
        if resp is not None:
            events_txt = json.loads(resp)

            events = events_txt['events']
            for event in events:
                bad_keys = ['linescores', 'statistics', 'leaders',  'records']
                for k in bad_keys:
                    if k in event['competitions'][0]['competitors'][0].keys():
                        del event['competitions'][0]['competitors'][0][k]
                    if k in event['competitions'][0]['competitors'][1].keys():
                        del event['competitions'][0]['competitors'][1][k]
                if 'links' in event['competitions'][0]['competitors'][0]['team'].keys():
                    del event['competitions'][0]['competitors'][0]['team']['links']
                if 'links' in event['competitions'][0]['competitors'][1]['team'].keys():
                    del event['competitions'][0]['competitors'][1]['team']['links']    
                if event['competitions'][0]['competitors'][0]['homeAway']=='home':
                    event['competitions'][0]['home'] = event['competitions'][0]['competitors'][0]['team']    
                else: 
                    event['competitions'][0]['away'] = event['competitions'][0]['competitors'][0]['team']
                if event['competitions'][0]['competitors'][1]['homeAway']=='away':
                    event['competitions'][0]['away'] = event['competitions'][0]['competitors'][1]['team']
                else: 
                    event['competitions'][0]['home'] = event['competitions'][0]['competitors'][1]['team']

                del_keys = ['competitors', 'broadcasts','geoBroadcasts', 'headlines']
                for k in del_keys:
                    if k in event['competitions'][0].keys():
                        del event['competitions'][0][k]

                ev = ev.append(pd.json_normalize(event['competitions'][0]))
            i+=1
            ev['season']=year
        else:
            i+=1
            continue
    return ev

schedule_table = pd.DataFrame()
schedule = {}
for x in reversed(range(2002,2003)):
    year_schedule = wbb_schedule(x)
    year_schedule.to_csv(f"wbb/schedules/wbb_games_info_{x}.csv")
    schedule_table = schedule_table.append(year_schedule)
    year_schedule.to_json(orient='records')
    schedule[x]=year_schedule
    
data_dict = {
    key: schedule[key].to_dict(orient='records')
    for key in schedule.keys()
}

with open('wbb_schedule.json','w') as fp:
    json.dump(
    data_dict,
    fp,
    indent=4,
    sort_keys=True)

schedule_table.to_csv('wbb_games_info_2002_2021.csv')
    
# event['competitions'][0]
# Out:
# Working on 2002: 1 of 127, date: 20011109
# Working on 2002: 2 of 127, date: 20011111
# Working on 2002: 3 of 127, date: 20011115
# Working on 2002: 4 of 127, date: 20011116
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011116&limit=1000
# Working on 2002: 5 of 127, date: 20011117
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011117&limit=1000
# Working on 2002: 6 of 127, date: 20011118
# Working on 2002: 7 of 127, date: 20011119
# Working on 2002: 8 of 127, date: 20011120
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011120&limit=1000
# Working on 2002: 9 of 127, date: 20011121
# Working on 2002: 10 of 127, date: 20011122
# Working on 2002: 11 of 127, date: 20011123
# Working on 2002: 12 of 127, date: 20011124
# Working on 2002: 13 of 127, date: 20011125
# Working on 2002: 14 of 127, date: 20011126
# Working on 2002: 15 of 127, date: 20011127
# Working on 2002: 16 of 127, date: 20011128
# Working on 2002: 17 of 127, date: 20011129
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011129&limit=1000
# Working on 2002: 18 of 127, date: 20011130
# Working on 2002: 19 of 127, date: 20011201
# Working on 2002: 20 of 127, date: 20011202
# Working on 2002: 21 of 127, date: 20011203
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011203&limit=1000
# Working on 2002: 22 of 127, date: 20011204
# Working on 2002: 23 of 127, date: 20011205
# Working on 2002: 24 of 127, date: 20011206
# Working on 2002: 25 of 127, date: 20011207
# Working on 2002: 26 of 127, date: 20011208
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011208&limit=1000
# Working on 2002: 27 of 127, date: 20011209
# Working on 2002: 28 of 127, date: 20011210
# Working on 2002: 29 of 127, date: 20011211
# Working on 2002: 30 of 127, date: 20011212
# Working on 2002: 31 of 127, date: 20011213
# Working on 2002: 32 of 127, date: 20011214
# Working on 2002: 33 of 127, date: 20011215
# Working on 2002: 34 of 127, date: 20011216
# Working on 2002: 35 of 127, date: 20011217
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011217&limit=1000
# Working on 2002: 36 of 127, date: 20011218
# Working on 2002: 37 of 127, date: 20011219
# Working on 2002: 38 of 127, date: 20011220
# Working on 2002: 39 of 127, date: 20011221
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011221&limit=1000
# Working on 2002: 40 of 127, date: 20011222
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011222&limit=1000
# Working on 2002: 41 of 127, date: 20011223
# Working on 2002: 42 of 127, date: 20011227
# Working on 2002: 43 of 127, date: 20011228
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011228&limit=1000
# Working on 2002: 44 of 127, date: 20011229
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20011229&limit=1000
# Working on 2002: 45 of 127, date: 20011230
# Working on 2002: 46 of 127, date: 20011231
# Working on 2002: 47 of 127, date: 20020101
# Working on 2002: 48 of 127, date: 20020102
# Working on 2002: 49 of 127, date: 20020103
# Working on 2002: 50 of 127, date: 20020104
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020104&limit=1000
# Working on 2002: 51 of 127, date: 20020105
# Working on 2002: 52 of 127, date: 20020106
# Working on 2002: 53 of 127, date: 20020107
# Working on 2002: 54 of 127, date: 20020108
# Working on 2002: 55 of 127, date: 20020109
# Working on 2002: 56 of 127, date: 20020110
# Working on 2002: 57 of 127, date: 20020111
# Working on 2002: 58 of 127, date: 20020112
# Working on 2002: 59 of 127, date: 20020113
# Working on 2002: 60 of 127, date: 20020114
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Download error: Bad Gateway http://site.api.espn.com/apis/site/v2/sports/basketball/womens-college-basketball/scoreboard?groups=50&dates=20020114&limit=1000
# Working on 2002: 61 of 127, date: 20020115
# Working on 2002: 62 of 127, date: 20020116
# Working on 2002: 63 of 127, date: 20020117
# Working on 2002: 64 of 127, date: 20020118
# Working on 2002: 65 of 127, date: 20020119
# Working on 2002: 66 of 127, date: 20020120
# Working on 2002: 67 of 127, date: 20020121
# Working on 2002: 68 of 127, date: 20020122
# Working on 2002: 69 of 127, date: 20020123
# Working on 2002: 70 of 127, date: 20020124
# Working on 2002: 71 of 127, date: 20020125
# Working on 2002: 72 of 127, date: 20020126
# Working on 2002: 73 of 127, date: 20020127
# Working on 2002: 74 of 127, date: 20020128
# Working on 2002: 75 of 127, date: 20020129
# Working on 2002: 76 of 127, date: 20020130
# Working on 2002: 77 of 127, date: 20020131
# Working on 2002: 78 of 127, date: 20020201
# Working on 2002: 79 of 127, date: 20020202
# Working on 2002: 80 of 127, date: 20020203
# Working on 2002: 81 of 127, date: 20020204
# Working on 2002: 82 of 127, date: 20020205
# Working on 2002: 83 of 127, date: 20020206
# Working on 2002: 84 of 127, date: 20020207
# Working on 2002: 85 of 127, date: 20020208
# Working on 2002: 86 of 127, date: 20020209
# Working on 2002: 87 of 127, date: 20020210
# Working on 2002: 88 of 127, date: 20020211
# Working on 2002: 89 of 127, date: 20020212
# Working on 2002: 90 of 127, date: 20020213
# Working on 2002: 91 of 127, date: 20020214
# Working on 2002: 92 of 127, date: 20020215
# Working on 2002: 93 of 127, date: 20020216
# Working on 2002: 94 of 127, date: 20020217
# Working on 2002: 95 of 127, date: 20020218
# Working on 2002: 96 of 127, date: 20020219
# Working on 2002: 97 of 127, date: 20020220
# Working on 2002: 98 of 127, date: 20020221
# Working on 2002: 99 of 127, date: 20020222
# Working on 2002: 100 of 127, date: 20020223
# Working on 2002: 101 of 127, date: 20020224
# Working on 2002: 102 of 127, date: 20020225
# Working on 2002: 103 of 127, date: 20020226
# Working on 2002: 104 of 127, date: 20020227
# Working on 2002: 105 of 127, date: 20020228
# Working on 2002: 106 of 127, date: 20020301
# Working on 2002: 107 of 127, date: 20020302
# Working on 2002: 108 of 127, date: 20020303
# Working on 2002: 109 of 127, date: 20020304
# Working on 2002: 110 of 127, date: 20020305
# Working on 2002: 111 of 127, date: 20020306
# Working on 2002: 112 of 127, date: 20020307
# Working on 2002: 113 of 127, date: 20020308
# Working on 2002: 114 of 127, date: 20020309
# Working on 2002: 115 of 127, date: 20020313
# Working on 2002: 116 of 127, date: 20020314
# Working on 2002: 117 of 127, date: 20020315
# Working on 2002: 118 of 127, date: 20020316
# Working on 2002: 119 of 127, date: 20020317
# Working on 2002: 120 of 127, date: 20020318
# Working on 2002: 121 of 127, date: 20020319
# Working on 2002: 122 of 127, date: 20020320
# Working on 2002: 123 of 127, date: 20020323
# Working on 2002: 124 of 127, date: 20020325
# Working on 2002: 125 of 127, date: 20020327
# Working on 2002: 126 of 127, date: 20020329
# Working on 2002: 127 of 127, date: 20020331

# %%
import glob
import pandas as pd
directoryPath = 'wbb/schedules/'
glued_data = pd.DataFrame()
for file_name in glob.glob(directoryPath+'*.csv'):
    x = pd.read_csv(file_name, low_memory=False)
    glued_data = pd.concat([glued_data,x],axis=0)
    
glued_data.to_csv('wbb_games_info_2002_2021.csv')
